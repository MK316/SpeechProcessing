# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/SpeechProcessing/blob/main/Speech_gTTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic [1]: Text-to-Speech using gTTS
# ## Learning source: [Video]("https://youtu.be/ngYRYMoIGu8") [5m45s]
# ---

# %%
#@markdown Step ⓿ {gTTS} package installation and import
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %% [markdown]
# ## Text object & save the output as a wav file
#
# See [Languages supported in gTTS]("https://gtts.readthedocs.io/en/latest/module.html#languages-gtts-lang")

# %%
#@markdown Step ⓵ Type text to say
text_to_say = input()
# Out:
# This is my first time to visit Korea. I'm so excited.

# %%
#@markdown Step ⓶ Language setting (english)
language = "en"
gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = False)

# %%
#@markdown Step ⓷ Create audio file and save it on colab
gtts_object.save("/content/gtts_en.wav")

# %%
#@markdown ⓸ Play the audio
print("Language (English): %s"%text_to_say)
Audio("/content/gtts_en.wav")
# Out:
# Language (English): This is my first time to visit Korea. I'm so excited.
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
# # Topic [2]: Try accented English: e.g., French, Korean, German, etc.
# By choosing different language optioins in gTTS
#
# ---

# %%
#@markdown French accent
# text_to_say = "This is my first sample read by gTTS."
language = "fr"
gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = False)

gtts_object.save("/content/gtts_fr.wav")

Audio("/content/gtts_fr.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Korean accent

text_to_say = input()
language = "ko"
gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = False)

gtts_object.save("/content/gtts_ko.wav")

Audio("/content/gtts_ko.wav")
# Out:
# How are you
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# * German

# %%
#@markdown German

language = "es"
gtts_object = gTTS(text = text_to_say,
                   lang = language,
                   slow = False)

gtts_object.save("/content/gtts_es.wav")

Audio("/content/gtts_es.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
#
# #Topic [3]: Speech recognition test using [speechnotes.co]("https://speechnotes.co")

# %% [markdown]
# ![FA_gtts.png](data:image/png;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/SpeechProcessing/blob/main/GithubAudioRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Needed imports
import numpy as np
from IPython.display import Audio
# from scipy.io import wavfile

# %%
colaboratory = True

if colaboratory:
    # Load sound file from GitHub
    # !wget https://github.com/MK316/workshops/raw/main/20230126_yonsei/data/one.wav
  
    # Erase output after import
    from IPython.display import clear_output
    clear_output()

    print("one.wav loaded")
else:
    print("We are not in colaboratory")
    print("The file shall already be in the computer")
# Out:
# one.wav loaded

# %%
data1 = "/content/one.wav"

# %%
framerate = 44100
Audio(data1,rate=framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
